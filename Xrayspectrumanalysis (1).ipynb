# %%
pip install roentgen
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 257.5/257.5 kB 11.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for roentgen: filename=roentgen-1.0-py3-none-any.whl size=171002 sha256=dd3375043aa9f16d0379dd1c94668185c0777f8bdded9f712c77e4734c1a72ef
#   Stored in directory: /root/.cache/pip/wheels/77/30/a8/6d9ea3e120aa9a6b1350b6f97a4e50ba55f2eb1425b92905b1
# Successfully built roentgen
# ...

# %%
from roentgen.absorption import MassAttenuationCoefficient
Cu_matten = MassAttenuationCoefficient('Cu')

# %%
import numpy as np
import matplotlib.pyplot as plt
import astropy.units as u
CU=[]
x=[]
energy = u.Quantity(7.5, 'keV')
from roentgen.absorption import Material
for i in np.arange(10, 50, 10):

  cu = Material('Cu', i * u.micron)
  CU.append(3342*cu.transmission(energy))
  x.append(i)




plt.plot(x,CU )

# %%
CU[1]-CU[0]
# Out:
# -794.3743618088556

# %%
CU
# Out:
# [1905.2774813011429, 1086.2005627627846, 619.2440073035793, 353.0316165607989]

# %%
# Out:
# 0.14173323145296302

# %%
cu = Material('Cu', 20 * u.micron)
cu.transmission(energy)
# Out:
# 0.020880741586574544

# %%
from roentgen.absorption import MassAttenuationCoefficient
si_matten = MassAttenuationCoefficient('Cu')

# %%
si_matten

# %%
si_matten.data[13]
# Out:
# <Quantity 215.9 cm2 / g>

# %%
import numpy as np
import matplotlib.pyplot as plt
import astropy.units as u

from roentgen.absorption import Material

al1 = Material('Cu', 10 * u.micron)
al2 = Material('Cu', 20 * u.micron)
al3 = Material('Cu', 30 * u.micron)
al4 = Material('Cu', 40 * u.micron)
al5 = Material('Cu', 50 * u.micron)
energy = u.Quantity(np.arange(1, 10, 0.007), 'keV')

plt.plot(energy, al1.transmission(energy))
plt.plot(energy, al2.transmission(energy))
plt.plot(energy, al3.transmission(energy))
plt.plot(energy, al4.transmission(energy))
plt.plot(energy, al5.transmission(energy))
plt.ylabel('Transmission')
plt.xlabel('Energy [' + str(energy.unit) + ']')
plt.title(al.name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-0c86f94bcd69> in <cell line: 21>()
#      19 plt.ylabel('Transmission')
#      20 plt.xlabel('Energy [' + str(energy.unit) + ']')
# ---> 21 plt.title(al.name)
#
# NameError: name 'al' is not defined

# %%
plt.plot(energy, 10000000*al1.transmission(energy))

# %%
list(si_matten.energy).index(<Quantity 10. keV>)
# Out:
#   File "<ipython-input-17-d380c9fff0f5>", line 1
#     list(si_matten.energy).index(<Quantity 10. keV>)
#                                  ^
# SyntaxError: invalid syntax

# %%
list(si_matten.energy)
# Out:
# [<Quantity 1. keV>,
#  <Quantity 1.047 keV>,
#  <Quantity 1.096 keV>,
#  <Quantity 1.096 keV>,
#  <Quantity 1.5 keV>,
#  <Quantity 2. keV>,
#  <Quantity 3. keV>,
#  <Quantity 4. keV>,
#  <Quantity 5. keV>,
#  <Quantity 6. keV>,
#  <Quantity 8. keV>,
#  <Quantity 8.979 keV>,
#  <Quantity 8.979 keV>,
#  <Quantity 10. keV>,
#  <Quantity 15. keV>,
#  <Quantity 20. keV>,
#  <Quantity 30. keV>,
#  <Quantity 40. keV>,
#  <Quantity 50. keV>,
#  <Quantity 60. keV>,
#  <Quantity 80. keV>,
#  <Quantity 100. keV>,
#  <Quantity 150. keV>,
#  <Quantity 200. keV>,
#  <Quantity 300. keV>,
#  <Quantity 400. keV>,
#  <Quantity 500. keV>,
#  <Quantity 600. keV>,
#  <Quantity 800. keV>,
#  <Quantity 1000. keV>,
#  <Quantity 1250. keV>,
#  <Quantity 1500. keV>,
#  <Quantity 2000. keV>,
#  <Quantity 3000. keV>,
#  <Quantity 4000. keV>,
#  <Quantity 5000. keV>,
#  <Quantity 6000. keV>,
#  <Quantity 8000. keV>,
#  <Quantity 10000. keV>,
#  <Quantity 15000. keV>,
#  <Quantity 20000. keV>]
